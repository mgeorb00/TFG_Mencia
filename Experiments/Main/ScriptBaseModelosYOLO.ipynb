# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Cargar el modelo preentrenado -> Aquí se tiene que especificar el modelo que se quiere utilizar
model = YOLO('yolov8l.pt')

# %%
# Entrenar
model.train(
    data=ruta_yaml, #Ruta en la que se encuentra el .yaml del dataset que se va a utilizar para entrenar
    epochs=200,
    patience=20,
    imgsz=640,
    batch=8,
    device=0
)

# %%
# Evaluar sobre el dataset
metrics = model.val(data=ruta_yaml, plots=True) #Se especifica la ruta al .yaml que se va a utilizar para validar

# Mostrar resultados
print(metrics)

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark en GPU (requiere Nvidia)
benchmark(model="ruta_best.pt", imgsz=640, device=0)
